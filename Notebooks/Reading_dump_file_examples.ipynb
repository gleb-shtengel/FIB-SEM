# %%
import pickle
import numpy as np

# %% [markdown]
# # Read Dump File

# %%
dump_filename = 'Y:/GLOBUS/Megaphragma_2024_3n3_transformed/Megaphragma_2024_3n3_v2_notebook_and_results/Registered_brat0.00_params.bin'
dump_data = pickle.load(open(dump_filename, 'rb'))

# %% [markdown]
# # It has FIBSEM_dataset object attributes saves as a dictionary

# %%
list(dump_data.keys())
# Out:
# ['fls',
#  'fnms',
#  'nfrs',
#  'data_dir',
#  'ftype',
#  'XResolution',
#  'YResolution',
#  'Scaling',
#  'PixelSize',
#  'voxel_size',
#  'DetA',
#  'DetB',
#  'ImgB_fraction',
#  'Sample_ID',
#  'EightBit',
#  'use_DASK',
#  'DASK_client_retries',
#  'threshold_min',
#  'threshold_max',
#  'nbins',
#  'sliding_minmax',
#  'TransformType',
#  'tr_matr_cum_residual',
#  'l2_matrix',
#  'targ_vector',
#  'solver',
#  'RANSAC_initial_fraction',
#  'drmax',
#  'max_iter',
#  'BFMatcher',
#  'save_matches',
#  'SIFT_nfeatures',
#  'SIFT_nOctaveLayers',
#  'SIFT_contrastThreshold',
#  'SIFT_edgeThreshold',
#  'SIFT_sigma',
#  'save_res_png',
#  'zbin_factor',
#  'eval_metrics',
#  'fnm_types',
#  'flipY',
#  'preserve_scales',
#  'fit_params',
#  'int_order',
#  'subtract_linear_fit',
#  'subtract_FOVtrend_from_fit',
#  'FOVtrend_x',
#  'FOVtrend_y',
#  'pad_edges',
#  'perform_deformation',
#  'deformation_type',
#  'deformation_sigma',
#  'fnm_reg',
#  'dtp',
# ...

# %% [markdown]
# ## For example, all processed initial Raw data files (".dat" files)

# %%
print(len(dump_data['fls']))
dump_data['fls']
# Out:
# 18923
# ['/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_000337_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_003940_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_011542_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_015145_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_022749_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_030352_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_033955_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_041558_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_045202_0-0-0.dat',
#  '/groups/hess/hesslab/Megaphragma/Y2024/M10/D31/Merlin-6285_24-10-31_052805_0-0-0.dat',
# ...

# %% [markdown]
# ## Another example, processed transformation matrix

# %%
print(len(dump_data['tr_matr_cum_residual']))
dump_data['tr_matr_cum_residual']
# Out:
# 18923
# array([[[ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  1.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]],
#
#        [[ 1.00000000e+00,  0.00000000e+00, -1.82393039e-02],
#         [ 0.00000000e+00,  1.00000000e+00,  6.99183192e-03],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]],
#
#        [[ 1.00000000e+00,  0.00000000e+00, -3.64786078e-02],
#         [ 0.00000000e+00,  1.00000000e+00,  1.39836638e-02],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]],
#
#        ...,
#
#        [[ 9.99989472e-01, -1.36822146e-05,  2.84210860e+02],
#         [-2.86287075e-06,  1.00000687e+00, -8.12785753e+01],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]],
#
#        [[ 9.99973820e-01, -1.31531941e-05,  2.84084031e+02],
#         [-9.28098516e-06,  1.00006229e+00, -8.17625837e+01],
#         [ 0.00000000e+00,  0.00000000e+00,  1.00000000e+00]],
#
# ...
